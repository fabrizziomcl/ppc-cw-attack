# %%
# !pip install kaggle --quiet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/keys/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, models, transforms
from torch.utils.data import DataLoader, random_split, Dataset
from PIL import Image
import time
# Configurar dispositivo (GPU si está disponible)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Usando dispositivo: {device}")
# Out:
# Usando dispositivo: cuda:0

# %%
# --- Celda 2: Subir tu Framework de Ataque ---
# !mkdir -p attacks
# !mkdir -p models

print("\nPor favor, sube tus archivos .py del framework usando el panel de la izquierda.")
print("Sube a 'attacks/': base.py, carlini_wagner.py")
print("Sube a 'models/': base_models.py, pytorch.py")
print("Sube al directorio raíz: adversarial.py, criteria.py, distances.py, utils.py")
# Out:
# Por favor, sube tus archivos .py del framework usando el panel de la izquierda.
# Sube a 'attacks/': base.py, carlini_wagner.py
# Sube a 'models/': base_models.py, pytorch.py
# Sube al directorio raíz: adversarial.py, criteria.py, distances.py, utils.py

# %%
import os
from google.colab import files

# %%
# --- Celda 3: Descarga y Preparación del Dataset (CORREGIDA) ---
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, Dataset
from PIL import Image
import os

# Descargar y descomprimir el dataset
# !kaggle competitions download -c sci-pediatric-chest-x-ray-pneumonia-classificatio --force -q
# !unzip -oq "sci-pediatric-chest-x-ray-pneumonia-classificatio.zip"

# --- RUTAS CORRECTAS ---
train_dir = 'train/train'  # Apunta al directorio que contiene las carpetas NORMAL/PNEUMONIA
test_dir = 'test/test'      # Apunta al directorio con todas las imágenes de prueba juntas

print(f"Directorio de entrenamiento usado: {train_dir}")
print(f"Directorio de prueba usado: {test_dir}")

# --- Transformaciones de Imagen para ResNet ---
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Grayscale(num_output_channels=3), # ResNet espera 3 canales
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val_test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Grayscale(num_output_channels=3),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# --- LÓGICA DE SPLIT (imitando a TensorFlow) ---
full_train_dataset = datasets.ImageFolder(train_dir, transform=data_transforms['val_test'])
train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = random_split(full_train_dataset, [train_size, val_size])
train_dataset.dataset.transform = data_transforms['train'] # Aplicar aumentación solo a train

# --- CLASE DATASET PERSONALIZADA PARA EL TEST SET (sin carpetas de clase) ---
class UnlabeledImageFolder(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = sorted([f for f in os.listdir(root_dir) if os.path.isfile(os.path.join(root_dir, f))])

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        # Devolvemos un label ficticio (ej. -1) porque el dataloader lo requiere, pero no lo usaremos
        return image, -1

test_dataset = UnlabeledImageFolder(test_dir, transform=data_transforms['val_test'])

# --- CREAR DATALOADERS ---
dataloaders = {
    'train': DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2),
    'val': DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2),
    'test': DataLoader(test_dataset, batch_size=1, shuffle=False) # No barajar para mantener el orden
}

class_names = full_train_dataset.classes
print(f"\nClases encontradas: {class_names}")
print(f"Tamaño del set de entrenamiento: {len(train_dataset)}")
print(f"Tamaño del set de validación: {len(val_dataset)}")
print(f"Tamaño del set de prueba: {len(test_dataset)}")
# Out:
# Directorio de entrenamiento usado: train/train
# Directorio de prueba usado: test/test
#
# Clases encontradas: ['NORMAL', 'PNEUMONIA']
# Tamaño del set de entrenamiento: 3052
# Tamaño del set de validación: 764
# Tamaño del set de prueba: 2040

# %%
# --- Transformaciones de Imagen para ResNet ---
data_transforms = {
    'train': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Grayscale(num_output_channels=3), # ResNet espera 3 canales
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
    'val_test': transforms.Compose([
        transforms.Resize((224, 224)),
        transforms.Grayscale(num_output_channels=3),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ]),
}

# --- LÓGICA DE SPLIT ---
full_train_dataset = datasets.ImageFolder(train_dir, transform=data_transforms['val_test'])
train_size = int(0.8 * len(full_train_dataset))
val_size = len(full_train_dataset) - train_size
train_dataset, val_dataset = random_split(full_train_dataset, [train_size, val_size])
train_dataset.dataset.transform = data_transforms['train']

# --- CLASE DATASET PERSONALIZADA PARA EL TEST SET ---
class UnlabeledImageFolder(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.image_files = sorted([f for f in os.listdir(root_dir) if os.path.isfile(os.path.join(root_dir, f))])

    def __len__(self):
        return len(self.image_files)

    def __getitem__(self, idx):
        img_path = os.path.join(self.root_dir, self.image_files[idx])
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        # Devolvemos un label ficticio (ej. -1), no lo usaremos
        return image, -1

test_dataset = UnlabeledImageFolder(test_dir, transform=data_transforms['val_test'])

# --- CREAR DATALOADERS Y DICCIONARIO DE DATASETS ---
image_datasets = {'train': train_dataset, 'val': val_dataset, 'test': test_dataset}
dataloaders = {
    'train': DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=2),
    'val': DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=2),
    'test': DataLoader(test_dataset, batch_size=1, shuffle=False)
}

class_names = full_train_dataset.classes
print(f"\nClases encontradas: {class_names}")
print(f"Tamaño del set de entrenamiento: {len(train_dataset)}")
print(f"Tamaño del set de validación: {len(val_dataset)}")
print(f"Tamaño del set de prueba: {len(test_dataset)}")
# Out:
# Clases encontradas: ['NORMAL', 'PNEUMONIA']
# Tamaño del set de entrenamiento: 3052
# Tamaño del set de validación: 764
# Tamaño del set de prueba: 2040

# %%
import torch
from torchvision import models
from torchvision.models import inception_v3, Inception_V3_Weights

# 1) Selección de dispositivo
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2) Instanciar y cargar modelos preentrenados
resnet50_model        = models.resnet50(pretrained=True).to(device).eval()
densenet121_model     = models.densenet121(pretrained=True).to(device).eval()
efficientnet_b0_model = models.efficientnet_b0(pretrained=True).to(device).eval()
inception_v3_model    = inception_v3(weights=Inception_V3_Weights.IMAGENET1K_V1).to(device).eval()
vgg19_model           = models.vgg19(pretrained=True).to(device).eval()

# 3) Diccionario de modelos a evaluar
models = {
    "ResNet50":        resnet50_model,
    "DenseNet121":     densenet121_model,
    "EfficientNetB0":  efficientnet_b0_model,
    "InceptionV3":     inception_v3_model,
    "VGG19":           vgg19_model,
}
# Out:
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:01<00:00, 86.9MB/s]
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg19-dcbb9e9d.pth" to /root/.cache/torch/hub/checkpoints/vgg19-dcbb9e9d.pth
# 100%|██████████| 548M/548M [00:06<00:00, 83.3MB/s]

# %%
# Mean/std de ImageNet para canales RGB
imagenet_mean = np.array([0.485, 0.456, 0.406])
imagenet_std  = np.array([0.229, 0.224, 0.225])

# Cálculo de bounds: min y max tras normalizar [0,1]
min_val = float(((0.0 - imagenet_mean) / imagenet_std).min())
max_val = float(((1.0 - imagenet_mean) / imagenet_std).max())
bounds  = (min_val, max_val)

# Número de clases de tu detector de tomografías
NUM_CLASSES = 2   # ajusta si tienes más clases

# Ahora sí puedes instanciar PyTorchModel sin NameError:
fmodel = PyTorchModel(
    model.to(device).eval(),
    bounds=bounds,
    num_classes=NUM_CLASSES,
    channel_axis=1,
    device=device
)

# %%
# --- Celda 4: Entrenamiento de Múltiples Modelos ---
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models
import time, copy

# 1) Configurar dispositivo y parámetros generales
device     = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_epochs = 10
lr         = 1e-3
criterion  = nn.CrossEntropyLoss()

# 2) Definir los modelos a entrenar (pre-trained) y su nombre de archivo de guardado
model_constructors = {
    "resnet18":   lambda: models.resnet18(pretrained=True),
    "resnet50":   lambda: models.resnet50(pretrained=True),
    "densenet121":lambda: models.densenet121(pretrained=True),
    "efficientnet_b0": lambda: models.efficientnet_b0(pretrained=True),
    "vgg19":      lambda: models.vgg19(pretrained=True),
}

for name, constructor in model_constructors.items():
    print(f"\n=== Entrenando {name} ===")

    # 3) Instanciar y adaptar la última capa
    model = constructor()
    if "resnet" in name:
        num_ftrs       = model.fc.in_features
        model.fc       = nn.Linear(num_ftrs, len(class_names))
    elif "densenet" in name:
        num_ftrs       = model.classifier.in_features
        model.classifier = nn.Linear(num_ftrs, len(class_names))
    elif "efficientnet" in name:
        num_ftrs        = model.classifier[1].in_features
        model.classifier[1] = nn.Linear(num_ftrs, len(class_names))
    elif "vgg" in name:
        num_ftrs       = model.classifier[-1].in_features
        model.classifier[-1] = nn.Linear(num_ftrs, len(class_names))
    else:  # inception_v3
        num_ftrs       = model.fc.in_features
        model.fc       = nn.Linear(num_ftrs, len(class_names))
        # si usas aux_logits=True, también ajustarías model.AuxLogits.fc

    model = model.to(device)
    optimizer = optim.Adam(model.parameters(), lr=lr)

    # 4) Bucle de entrenamiento / validación
    best_acc       = 0.0
    save_path      = f"{name}_best.pth"
    since          = time.time()

    for epoch in range(num_epochs):
        print(f"[{name}] Epoch {epoch+1}/{num_epochs}")
        for phase in ("train", "val"):
            model.train() if phase=="train" else model.eval()
            running_loss, running_corrects = 0.0, 0

            for inputs, labels in dataloaders[phase]:
                inputs, labels = inputs.to(device), labels.to(device)
                optimizer.zero_grad()
                with torch.set_grad_enabled(phase=="train"):
                    outputs = model(inputs)
                    _, preds = torch.max(outputs, 1)
                    loss = criterion(outputs, labels)
                    if phase=="train":
                        loss.backward()
                        optimizer.step()
                running_loss     += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(image_datasets[phase])
            epoch_acc  = running_corrects.double() / len(image_datasets[phase])
            print(f" {phase}  Loss: {epoch_loss:.4f}  Acc: {epoch_acc:.4f}")

            # Guardar mejor modelo de validación
            if phase=="val" and epoch_acc > best_acc:
                best_acc = epoch_acc
                torch.save(model.state_dict(), save_path)
                print(f"  -> Nuevo mejor modelo guardado: {save_path}")

    elapsed = time.time() - since
    print(f"[{name}] Entrenamiento completado en {elapsed//60:.0f}m {elapsed%60:.0f}s, Mejor Acc: {best_acc:.4f}")
# Out:
# === Entrenando resnet18 ===
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 83.6MB/s]
# [resnet18] Epoch 1/10
#  train  Loss: 0.1891  Acc: 0.9292
#  val  Loss: 0.1336  Acc: 0.9411
#   -> Nuevo mejor modelo guardado: resnet18_best.pth
# [resnet18] Epoch 2/10
#  train  Loss: 0.1363  Acc: 0.9499
#  val  Loss: 0.1177  Acc: 0.9542
#   -> Nuevo mejor modelo guardado: resnet18_best.pth
# [resnet18] Epoch 3/10
#  train  Loss: 0.1031  Acc: 0.9620
#  val  Loss: 0.4192  Acc: 0.8809
# [resnet18] Epoch 4/10
#  train  Loss: 0.0903  Acc: 0.9685
#  val  Loss: 0.1069  Acc: 0.9620
#   -> Nuevo mejor modelo guardado: resnet18_best.pth
# [resnet18] Epoch 5/10
#  train  Loss: 0.0936  Acc: 0.9682
#  val  Loss: 0.1070  Acc: 0.9555
# [resnet18] Epoch 6/10
#  train  Loss: 0.0722  Acc: 0.9744
#  val  Loss: 0.1159  Acc: 0.9634
#   -> Nuevo mejor modelo guardado: resnet18_best.pth
# [resnet18] Epoch 7/10
#  train  Loss: 0.0989  Acc: 0.9636
#  val  Loss: 0.0988  Acc: 0.9607
# [resnet18] Epoch 8/10
#  train  Loss: 0.0777  Acc: 0.9715
#  val  Loss: 0.1291  Acc: 0.9463
# [resnet18] Epoch 9/10
#  train  Loss: 0.0694  Acc: 0.9767
#  val  Loss: 0.0797  Acc: 0.9699
#   -> Nuevo mejor modelo guardado: resnet18_best.pth
# [resnet18] Epoch 10/10
#  train  Loss: 0.0717  Acc: 0.9751
#  val  Loss: 0.1461  Acc: 0.9503
# [resnet18] Entrenamiento completado en 9m 50s, Mejor Acc: 0.9699
#
# === Entrenando resnet50 ===
# [resnet50] Epoch 1/10
#  train  Loss: 0.1948  Acc: 0.9243
#  val  Loss: 0.1360  Acc: 0.9516
#   -> Nuevo mejor modelo guardado: resnet50_best.pth
# [resnet50] Epoch 2/10
#  train  Loss: 0.1518  Acc: 0.9423
#  val  Loss: 0.2885  Acc: 0.9123
# [resnet50] Epoch 3/10
#  train  Loss: 0.1400  Acc: 0.9499
#  val  Loss: 0.1450  Acc: 0.9398
# [resnet50] Epoch 4/10
#  train  Loss: 0.1288  Acc: 0.9515
#  val  Loss: 0.1529  Acc: 0.9319
# [resnet50] Epoch 5/10
#  train  Loss: 0.1142  Acc: 0.9594
#  val  Loss: 0.0890  Acc: 0.9634
#   -> Nuevo mejor modelo guardado: resnet50_best.pth
# [resnet50] Epoch 6/10
#  train  Loss: 0.1020  Acc: 0.9623
#  val  Loss: 0.1536  Acc: 0.9359
# [resnet50] Epoch 7/10
#  train  Loss: 0.0949  Acc: 0.9653
#  val  Loss: 0.6768  Acc: 0.8010
# [resnet50] Epoch 8/10
#  train  Loss: 0.0925  Acc: 0.9643
#  val  Loss: 0.1822  Acc: 0.9280
# [resnet50] Epoch 9/10
#  train  Loss: 0.0962  Acc: 0.9659
#  val  Loss: 0.1474  Acc: 0.9437
# [resnet50] Epoch 10/10
#  train  Loss: 0.0767  Acc: 0.9705
#  val  Loss: 0.1867  Acc: 0.9385
# [resnet50] Entrenamiento completado en 11m 1s, Mejor Acc: 0.9634
#
# === Entrenando densenet121 ===
# [densenet121] Epoch 1/10
#  train  Loss: 0.1813  Acc: 0.9292
#  val  Loss: 0.3906  Acc: 0.9005
#   -> Nuevo mejor modelo guardado: densenet121_best.pth
# [densenet121] Epoch 2/10
#  train  Loss: 0.1290  Acc: 0.9531
#  val  Loss: 0.1051  Acc: 0.9620
#   -> Nuevo mejor modelo guardado: densenet121_best.pth
# [densenet121] Epoch 3/10
#  train  Loss: 0.1101  Acc: 0.9558
#  val  Loss: 0.1124  Acc: 0.9620
# [densenet121] Epoch 4/10
#  train  Loss: 0.1151  Acc: 0.9620
#  val  Loss: 0.1031  Acc: 0.9607
# [densenet121] Epoch 5/10
#  train  Loss: 0.0834  Acc: 0.9685
#  val  Loss: 0.0838  Acc: 0.9660
#   -> Nuevo mejor modelo guardado: densenet121_best.pth
# [densenet121] Epoch 6/10
#  train  Loss: 0.0737  Acc: 0.9758
#  val  Loss: 0.0823  Acc: 0.9686
#   -> Nuevo mejor modelo guardado: densenet121_best.pth
# [densenet121] Epoch 7/10
#  train  Loss: 0.0719  Acc: 0.9754
#  val  Loss: 0.0780  Acc: 0.9751
#   -> Nuevo mejor modelo guardado: densenet121_best.pth
# [densenet121] Epoch 8/10
#  train  Loss: 0.0713  Acc: 0.9738
#  val  Loss: 0.0864  Acc: 0.9647
# [densenet121] Epoch 9/10
#  train  Loss: 0.0568  Acc: 0.9767
#  val  Loss: 0.0925  Acc: 0.9647
# [densenet121] Epoch 10/10
#  train  Loss: 0.0574  Acc: 0.9807
#  val  Loss: 0.0946  Acc: 0.9660
# [densenet121] Entrenamiento completado en 11m 1s, Mejor Acc: 0.9751
#
# === Entrenando efficientnet_b0 ===
# [efficientnet_b0] Epoch 1/10
#  train  Loss: 0.2031  Acc: 0.9217
#  val  Loss: 0.1114  Acc: 0.9620
#   -> Nuevo mejor modelo guardado: efficientnet_b0_best.pth
# [efficientnet_b0] Epoch 2/10
#  train  Loss: 0.0973  Acc: 0.9643
#  val  Loss: 0.1279  Acc: 0.9490
# [efficientnet_b0] Epoch 3/10
#  train  Loss: 0.0766  Acc: 0.9708
#  val  Loss: 0.0732  Acc: 0.9804
#   -> Nuevo mejor modelo guardado: efficientnet_b0_best.pth
# [efficientnet_b0] Epoch 4/10
#  train  Loss: 0.0660  Acc: 0.9744
#  val  Loss: 0.0843  Acc: 0.9699
# [efficientnet_b0] Epoch 5/10
#  train  Loss: 0.0533  Acc: 0.9823
#  val  Loss: 0.1093  Acc: 0.9503
# [efficientnet_b0] Epoch 6/10
#  train  Loss: 0.0400  Acc: 0.9862
#  val  Loss: 0.0877  Acc: 0.9777
# [efficientnet_b0] Epoch 7/10
#  train  Loss: 0.0608  Acc: 0.9817
#  val  Loss: 0.1832  Acc: 0.9555
# [efficientnet_b0] Epoch 8/10
#  train  Loss: 0.0598  Acc: 0.9774
#  val  Loss: 0.0570  Acc: 0.9751
# [efficientnet_b0] Epoch 9/10
#  train  Loss: 0.0350  Acc: 0.9859
#  val  Loss: 0.0978  Acc: 0.9647
# [efficientnet_b0] Epoch 10/10
#  train  Loss: 0.0314  Acc: 0.9885
#  val  Loss: 0.0700  Acc: 0.9712
# [efficientnet_b0] Entrenamiento completado en 10m 6s, Mejor Acc: 0.9804
#
# === Entrenando vgg19 ===
# [vgg19] Epoch 1/10
#  train  Loss: 1.5686  Acc: 0.6920
#  val  Loss: 0.5804  Acc: 0.7435
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 2/10
#  train  Loss: 0.4961  Acc: 0.7664
#  val  Loss: 0.4424  Acc: 0.7461
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 3/10
#  train  Loss: 0.6064  Acc: 0.7356
#  val  Loss: 0.4377  Acc: 0.7435
# [vgg19] Epoch 4/10
#  train  Loss: 0.8165  Acc: 0.7143
#  val  Loss: 0.5589  Acc: 0.7435
# [vgg19] Epoch 5/10
#  train  Loss: 0.4206  Acc: 0.7942
#  val  Loss: 0.2206  Acc: 0.8992
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 6/10
#  train  Loss: 0.2807  Acc: 0.8827
#  val  Loss: 0.3640  Acc: 0.9058
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 7/10
#  train  Loss: 0.2996  Acc: 0.8935
#  val  Loss: 0.2034  Acc: 0.9162
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 8/10
#  train  Loss: 0.2514  Acc: 0.9017
#  val  Loss: 0.1873  Acc: 0.9306
#   -> Nuevo mejor modelo guardado: vgg19_best.pth
# [vgg19] Epoch 9/10
#  train  Loss: 0.4013  Acc: 0.8794
#  val  Loss: 0.3935  Acc: 0.8154
# [vgg19] Epoch 10/10
#  train  Loss: 0.5529  Acc: 0.8532
#  val  Loss: 0.4199  Acc: 0.8639
# [vgg19] Entrenamiento completado en 12m 55s, Mejor Acc: 0.9306

# %%
# --- Celda 5: Generación de Ejemplos Adversariales para Todos los Modelos Entrenados ---
import os, sys
import numpy as np
import torch
from torchvision import models
from tqdm.notebook import tqdm

# Asegúrate de añadir tu carpeta de trabajo al path para encontrar tus módulos
sys.path.insert(0, os.getcwd())

from models.pytorch import PyTorchModel
from attacks.carlini_wagner import CarliniWagnerL2Attack
from criteria import Misclassification
from distances import MeanSquaredDistance as MSE
from adversarial import Adversarial

# 1) Configuración general
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
N_SAMPLES = 100  # Número de adversariales por modelo
hypers = dict(binary_search_steps=5, max_iterations=100, learning_rate=1e-2)

# 2) Definir modelos y rutas a sus pesos
#    Cada constructor debe luego ajustar la capa final antes de cargar pesos
model_defs = {
    "resnet18":   (models.resnet18,   "resnet18_best.pth"),
    "resnet50":   (models.resnet50,   "resnet50_best.pth"),
    "densenet121":(models.densenet121,"densenet121_best.pth"),
    "efficientnet_b0": (models.efficientnet_b0, "efficientnet_b0_best.pth"),
    "vgg19":      (models.vgg19,      "vgg19_best.pth"),
}

# 3) Mean/std y bounds de ImageNet
mean = np.array([0.485, 0.456, 0.406])
std  = np.array([0.229, 0.224, 0.225])
min_val, max_val = float(((0 - mean)/std).min()), float(((1 - mean)/std).max())
bounds = (min_val, max_val)

# 4) Recoger resultados
results = {}

for name, (constructor, weight_path) in model_defs.items():
    print(f"\n--- Generando adv para {name} ---")
    # Instanciar modelo pre-trained=False y ajustar fc/classifier
    model = constructor(pretrained=False)
    num_classes = len(class_names)
    if name.startswith("resnet"):
        in_f = model.fc.in_features
        model.fc = torch.nn.Linear(in_f, num_classes)
    elif name.startswith("densenet"):
        in_f = model.classifier.in_features
        model.classifier = torch.nn.Linear(in_f, num_classes)
    elif name.startswith("efficientnet"):
        in_f = model.classifier[1].in_features
        model.classifier[1] = torch.nn.Linear(in_f, num_classes)
    elif name.startswith("vgg"):
        in_f = model.classifier[-1].in_features
        model.classifier[-1] = torch.nn.Linear(in_f, num_classes)
    # Mover e inspeccionar
    model.load_state_dict(torch.load(weight_path, map_location=device))
    model.to(device).eval()

    # Wrappear para adversarial framework
    fmodel = PyTorchModel(model,
                          bounds=bounds,
                          num_classes=num_classes,
                          channel_axis=1,
                          device=device)

    # Preparar el ataque
    attack = CarliniWagnerL2Attack()

    # Listas temporales para cada modelo
    benign_images, adv_images, distances = [], [], []
    count = 0

    # Generación con tqdm
    for data, _ in tqdm(dataloaders['test'], desc=f"{name} adv gen"):
        if count >= N_SAMPLES:
            break
        # De tensor a numpy y etiqueta original
        img_np = data.squeeze(0).permute(1,2,0).cpu().numpy()
        with torch.no_grad():
            orig_lbl = int(model(data.to(device)).argmax(dim=1))

        # Crear y ejecutar ataque
        adv = Adversarial(fmodel, Misclassification(), img_np, orig_lbl, distance=MSE)
        attack(adv, **hypers)

        # Si exitoso, almacenar
        if adv.image is not None:
            benign_images.append(img_np)
            adv_images.append(adv.image)
            distances.append(adv.distance.value)
            count += 1

    results[name] = dict(
        benign=benign_images,
        adversarial=adv_images,
        distance=distances
    )
    print(f"{name}: generados {count}/{N_SAMPLES}")
# Out:
# --- Generando adv para resnet18 ---
# resnet18 adv gen:   0%|          | 0/2040 [00:00<?, ?it/s]
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0037, Mejor L2: 2.5413
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0026, Mejor L2: 2.6460
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: 3.7092
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0018, Mejor L2: 7.2026
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0016, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0143, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1290, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.2642, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 11.3959, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 35.9161, Mejor L2: 5.3461
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0184, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1699, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.6683, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 14.7945, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 44.6278, Mejor L2: 5.4369
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0065, Mejor L2: 7.3947
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0040, Mejor L2: 7.3784
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 7.3639
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: 7.3584
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0072, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0598, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.5804, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 5.1778, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 12.8921, Mejor L2: 3.3589
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0112, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0970, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.9441, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 8.3059, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 19.5082, Mejor L2: 4.1642
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0086, Mejor L2: 7.7226
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0051, Mejor L2: 7.7040
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0034, Mejor L2: 7.6867
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0026, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0030, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0079, Mejor L2: 7.5556
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0048, Mejor L2: 7.5373
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0040, Mejor L2: inf
#   Fallo para const=3.8e-04. Nuevo límite inferior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 4.4e-04
#   Iteración 100/100, Pérdida: 0.0044, Mejor L2: 7.5349
#   Éxito para const=4.4e-04. Nuevo límite superior: 4.4e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0044, Mejor L2: 1.9220
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0030, Mejor L2: 2.1827
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: 2.6917
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: 3.8745
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0018, Mejor L2: 7.5320
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0088, Mejor L2: 7.6077
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0052, Mejor L2: 7.5872
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0034, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0043, Mejor L2: 7.5797
#   Éxito para const=3.8e-04. Nuevo límite superior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 3.1e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 7.5735
#   Éxito para const=3.1e-04. Nuevo límite superior: 3.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0091, Mejor L2: 7.8308
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0054, Mejor L2: 7.8133
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0036, Mejor L2: 7.7937
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0031, Mejor L2: 7.7872
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0061, Mejor L2: 8.1289
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0040, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0050, Mejor L2: 8.1218
#   Éxito para const=7.5e-04. Nuevo límite superior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 6.3e-04
#   Iteración 100/100, Pérdida: 0.0045, Mejor L2: 8.1164
#   Éxito para const=6.3e-04. Nuevo límite superior: 6.3e-04
#
# Búsqueda binaria paso 5/5, const = 5.6e-04
#   Iteración 100/100, Pérdida: 0.0042, Mejor L2: 8.1132
#   Éxito para const=5.6e-04. Nuevo límite superior: 5.6e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0077, Mejor L2: 7.7252
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0047, Mejor L2: 7.7061
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: 7.6888
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 7.6828
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0057, Mejor L2: 7.6554
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0037, Mejor L2: 7.6386
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 7.6286
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0163, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1480, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.4493, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 12.7981, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 30.6732, Mejor L2: 5.2532
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0054, Mejor L2: 3.9711
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0035, Mejor L2: 3.9528
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0026, Mejor L2: 3.9329
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 7.6279
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0082, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0686, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.6642, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 5.7667, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 18.4205, Mejor L2: 3.6961
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0066, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0519, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.5017, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 4.5270, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 15.0532, Mejor L2: 3.1217
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0078, Mejor L2: 7.8132
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0048, Mejor L2: 7.7949
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 7.7791
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0029, Mejor L2: 7.7732
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0077, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0648, Mejor L2: 7.1845
#   Éxito para const=1.0e-02. Nuevo límite superior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 5.5e-03
#   Iteración 100/100, Pérdida: 0.0362, Mejor L2: inf
#   Fallo para const=5.5e-03. Nuevo límite inferior: 5.5e-03
#
# Búsqueda binaria paso 4/5, const = 7.7e-03
#   Iteración 100/100, Pérdida: 0.0505, Mejor L2: 7.1819
#   Éxito para const=7.7e-03. Nuevo límite superior: 7.7e-03
#
# Búsqueda binaria paso 5/5, const = 6.6e-03
#   Iteración 100/100, Pérdida: 0.0433, Mejor L2: 7.1799
#   Éxito para const=6.6e-03. Nuevo límite superior: 6.6e-03
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0099, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0836, Mejor L2: 8.0849
#   Éxito para const=1.0e-02. Nuevo límite superior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 5.5e-03
#   Iteración 100/100, Pérdida: 0.0467, Mejor L2: 8.0775
#   Éxito para const=5.5e-03. Nuevo límite superior: 5.5e-03
#
# Búsqueda binaria paso 4/5, const = 3.2e-03
#   Iteración 100/100, Pérdida: 0.0283, Mejor L2: 8.0678
#   Éxito para const=3.2e-03. Nuevo límite superior: 3.2e-03
#
# Búsqueda binaria paso 5/5, const = 2.1e-03
#   Iteración 100/100, Pérdida: 0.0191, Mejor L2: 8.0590
#   Éxito para const=2.1e-03. Nuevo límite superior: 2.1e-03
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0154, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1414, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.3862, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 12.2444, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 29.4133, Mejor L2: 4.7708
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0081, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0657, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.6358, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 5.6638, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 12.0684, Mejor L2: 3.2835
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0042, Mejor L2: 2.5803
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 2.6823
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: 3.7639
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: 7.3103
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0017, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0128, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1145, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.1205, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.9556, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 24.3145, Mejor L2: 4.4286
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0077, Mejor L2: 7.7621
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0047, Mejor L2: 7.7442
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: 7.7287
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0049, Mejor L2: 4.0223
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 4.0068
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: 7.7631
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 7.7544
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0059, Mejor L2: 2.9593
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 2.9309
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 4.0928
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: 7.9391
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 7.9288
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0113, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1018, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.9945, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 8.5753, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 18.1684, Mejor L2: 3.9811
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0069, Mejor L2: 7.5332
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0043, Mejor L2: 7.5162
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0030, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0036, Mejor L2: 7.5105
#   Éxito para const=3.8e-04. Nuevo límite superior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 3.1e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 7.5064
#   Éxito para const=3.1e-04. Nuevo límite superior: 3.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0062, Mejor L2: 7.7235
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0039, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0050, Mejor L2: 7.7156
#   Éxito para const=7.5e-04. Nuevo límite superior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 6.3e-04
#   Iteración 100/100, Pérdida: 0.0045, Mejor L2: 7.7114
#   Éxito para const=6.3e-04. Nuevo límite superior: 6.3e-04
#
# Búsqueda binaria paso 5/5, const = 5.6e-04
#   Iteración 100/100, Pérdida: 0.0042, Mejor L2: 7.7081
#   Éxito para const=5.6e-04. Nuevo límite superior: 5.6e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0130, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1158, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.1295, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.7350, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 18.2142, Mejor L2: 4.0947
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0051, Mejor L2: 6.8602
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0041, Mejor L2: inf
#   Fallo para const=7.5e-04. Nuevo límite inferior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 8.8e-04
#   Iteración 100/100, Pérdida: 0.0046, Mejor L2: 6.8573
#   Éxito para const=8.8e-04. Nuevo límite superior: 8.8e-04
#
# Búsqueda binaria paso 5/5, const = 8.1e-04
#   Iteración 100/100, Pérdida: 0.0044, Mejor L2: 6.8558
#   Éxito para const=8.1e-04. Nuevo límite superior: 8.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0040, Mejor L2: 3.6104
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 6.9884
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 6.9779
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0017, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: 6.9743
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0135, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1208, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.1771, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.7759, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 29.5263, Mejor L2: 3.9106
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0172, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1586, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.5615, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 14.4577, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 69.9402, Mejor L2: inf
#   Fallo para const=1.0e+01. Nuevo límite inferior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
# /content/attacks/base.py:145: UserWarning: CarliniWagnerL2Attack did not find an adversarial, maybe the model or the criterion is not supported by this attack.
#   warnings.warn('{} did not find an adversarial, maybe the model'
#   Iteración 100/100, Pérdida: 0.0090, Mejor L2: 7.4900
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0053, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0071, Mejor L2: inf
#   Fallo para const=7.5e-04. Nuevo límite inferior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 8.8e-04
#   Iteración 100/100, Pérdida: 0.0081, Mejor L2: 7.4866
#   Éxito para const=8.8e-04. Nuevo límite superior: 8.8e-04
#
# Búsqueda binaria paso 5/5, const = 8.1e-04
#   Iteración 100/100, Pérdida: 0.0076, Mejor L2: inf
#   Fallo para const=8.1e-04. Nuevo límite inferior: 8.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0058, Mejor L2: 7.8416
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 7.8201
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 7.8055
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0102, Mejor L2: 7.9855
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0060, Mejor L2: 7.9656
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0039, Mejor L2: 7.9491
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0029, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0034, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0083, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0699, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.6757, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 5.6755, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 11.5235, Mejor L2: 3.2939
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0145, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1319, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.2924, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 11.3561, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 24.9113, Mejor L2: 4.7289
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0086, Mejor L2: 7.4194
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0050, Mejor L2: 7.4019
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 7.3861
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0029, Mejor L2: 7.3799
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0049, Mejor L2: 4.0270
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 4.0083
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: 7.7720
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: 7.7680
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0131, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1160, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.1337, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.9980, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 25.3935, Mejor L2: 4.7591
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0114, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0996, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.9684, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 8.2113, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 18.4954, Mejor L2: 3.9802
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0130, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1153, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.1266, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.9486, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 27.1965, Mejor L2: 4.3776
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0138, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1232, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.2021, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 10.2528, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 26.8668, Mejor L2: 4.8333
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 3.7770
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 3.7636
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 7.3067
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0018, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: 7.3049
#   Éxito para const=1.9e-04. Nuevo límite superior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0123, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1100, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.0718, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 9.1181, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 20.1739, Mejor L2: 4.2074
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0118, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1031, Mejor L2: 8.0574
#   Éxito para const=1.0e-02. Nuevo límite superior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 5.5e-03
#   Iteración 100/100, Pérdida: 0.0575, Mejor L2: 8.0502
#   Éxito para const=5.5e-03. Nuevo límite superior: 5.5e-03
#
# Búsqueda binaria paso 4/5, const = 3.2e-03
#   Iteración 100/100, Pérdida: 0.0346, Mejor L2: 8.0417
#   Éxito para const=3.2e-03. Nuevo límite superior: 3.2e-03
#
# Búsqueda binaria paso 5/5, const = 2.1e-03
#   Iteración 100/100, Pérdida: 0.0232, Mejor L2: 8.0338
#   Éxito para const=2.1e-03. Nuevo límite superior: 2.1e-03
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0094, Mejor L2: 7.7483
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0055, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0075, Mejor L2: 7.7398
#   Éxito para const=7.5e-04. Nuevo límite superior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 6.3e-04
#   Iteración 100/100, Pérdida: 0.0065, Mejor L2: 7.7350
#   Éxito para const=6.3e-04. Nuevo límite superior: 6.3e-04
#
# Búsqueda binaria paso 5/5, const = 5.6e-04
#   Iteración 100/100, Pérdida: 0.0060, Mejor L2: inf
#   Fallo para const=5.6e-04. Nuevo límite inferior: 5.6e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0086, Mejor L2: 8.0252
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0052, Mejor L2: 8.0062
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0035, Mejor L2: 7.9864
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 7.9699
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0063, Mejor L2: 8.1373
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0041, Mejor L2: 8.1138
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0030, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0035, Mejor L2: inf
#   Fallo para const=3.8e-04. Nuevo límite inferior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 4.4e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 8.1101
#   Éxito para const=4.4e-04. Nuevo límite superior: 4.4e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0076, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0621, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.6017, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 5.3463, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 11.5784, Mejor L2: 3.3710
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0083, Mejor L2: 7.6156
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0050, Mejor L2: 7.5976
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0041, Mejor L2: 7.5916
#   Éxito para const=3.8e-04. Nuevo límite superior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 3.1e-04
#   Iteración 100/100, Pérdida: 0.0037, Mejor L2: 7.5882
#   Éxito para const=3.1e-04. Nuevo límite superior: 3.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0146, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1325, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.2972, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 11.5597, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 31.4936, Mejor L2: 5.3599
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0070, Mejor L2: 7.0799
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0042, Mejor L2: 7.0648
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0035, Mejor L2: inf
#   Fallo para const=3.8e-04. Nuevo límite inferior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 4.4e-04
#   Iteración 100/100, Pérdida: 0.0039, Mejor L2: inf
#   Fallo para const=4.4e-04. Nuevo límite inferior: 4.4e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0146, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.1315, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 1.2850, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 11.1306, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 22.5917, Mejor L2: 4.4319
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0065, Mejor L2: 4.0159
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0041, Mejor L2: 3.9981
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0029, Mejor L2: 3.9805
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: 7.7143
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: 7.7029
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0101, Mejor L2: inf
#   Fallo para const=1.0e-03. Nuevo límite inferior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 1.0e-02
#   Iteración 100/100, Pérdida: 0.0859, Mejor L2: inf
#   Fallo para const=1.0e-02. Nuevo límite inferior: 1.0e-02
#
# Búsqueda binaria paso 3/5, const = 1.0e-01
#   Iteración 100/100, Pérdida: 0.8344, Mejor L2: inf
#   Fallo para const=1.0e-01. Nuevo límite inferior: 1.0e-01
#
# Búsqueda binaria paso 4/5, const = 1.0e+00
#   Iteración 100/100, Pérdida: 7.2568, Mejor L2: inf
#   Fallo para const=1.0e+00. Nuevo límite inferior: 1.0e+00
#
# Búsqueda binaria paso 5/5, const = 1.0e+01
#   Iteración 100/100, Pérdida: 16.6259, Mejor L2: 3.8263
#   Éxito para const=1.0e+01. Nuevo límite superior: 1.0e+01
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0059, Mejor L2: 7.7822
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: inf
#   Fallo para const=5.0e-04. Nuevo límite inferior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 7.5e-04
#   Iteración 100/100, Pérdida: 0.0048, Mejor L2: 7.7772
#   Éxito para const=7.5e-04. Nuevo límite superior: 7.5e-04
#
# Búsqueda binaria paso 4/5, const = 6.3e-04
#   Iteración 100/100, Pérdida: 0.0043, Mejor L2: 7.7731
#   Éxito para const=6.3e-04. Nuevo límite superior: 6.3e-04
#
# Búsqueda binaria paso 5/5, const = 5.6e-04
# ...
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: inf
#   Fallo para const=1.9e-04. Nuevo límite inferior: 1.9e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0060, Mejor L2: 3.9011
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0038, Mejor L2: 3.8867
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 7.5284
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: 7.5204
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0066, Mejor L2: 3.9194
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0041, Mejor L2: 3.9022
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0029, Mejor L2: 7.5506
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0023, Mejor L2: 7.5401
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0074, Mejor L2: 3.9323
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0045, Mejor L2: 7.5898
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0031, Mejor L2: 7.5690
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: 7.5560
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: inf
#   Fallo para const=6.3e-05. Nuevo límite inferior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0071, Mejor L2: 2.9038
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0044, Mejor L2: 4.0331
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0030, Mejor L2: 4.0159
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: 7.7828
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 7.7731
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0048, Mejor L2: 2.0621
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0033, Mejor L2: 2.3448
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0026, Mejor L2: 2.8940
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: 4.1622
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 8.0923
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0032, Mejor L2: 0.9570
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0024, Mejor L2: 0.9412
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0020, Mejor L2: 1.0603
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: 1.2926
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0018, Mejor L2: 1.9207
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0034, Mejor L2: 1.9349
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0025, Mejor L2: 2.0101
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0021, Mejor L2: 2.7302
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: 3.9154
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0018, Mejor L2: 7.6177
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0120, Mejor L2: 7.8424
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0068, Mejor L2: 7.8242
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0043, Mejor L2: inf
#   Fallo para const=2.5e-04. Nuevo límite inferior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 3.8e-04
#   Iteración 100/100, Pérdida: 0.0056, Mejor L2: 7.8164
#   Éxito para const=3.8e-04. Nuevo límite superior: 3.8e-04
#
# Búsqueda binaria paso 5/5, const = 3.1e-04
#   Iteración 100/100, Pérdida: 0.0049, Mejor L2: 7.8133
#   Éxito para const=3.1e-04. Nuevo límite superior: 3.1e-04
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0059, Mejor L2: 2.0489
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0037, Mejor L2: 2.2110
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0027, Mejor L2: 2.7144
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: 2.7787
#   Éxito para const=1.3e-04. Nuevo límite superior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 6.3e-05
#   Iteración 100/100, Pérdida: 0.0019, Mejor L2: 3.9137
#   Éxito para const=6.3e-05. Nuevo límite superior: 6.3e-05
#
# Búsqueda binaria paso 1/5, const = 1.0e-03
#   Iteración 100/100, Pérdida: 0.0065, Mejor L2: 7.5276
#   Éxito para const=1.0e-03. Nuevo límite superior: 1.0e-03
#
# Búsqueda binaria paso 2/5, const = 5.0e-04
#   Iteración 100/100, Pérdida: 0.0040, Mejor L2: 7.5095
#   Éxito para const=5.0e-04. Nuevo límite superior: 5.0e-04
#
# Búsqueda binaria paso 3/5, const = 2.5e-04
#   Iteración 100/100, Pérdida: 0.0028, Mejor L2: 7.4946
#   Éxito para const=2.5e-04. Nuevo límite superior: 2.5e-04
#
# Búsqueda binaria paso 4/5, const = 1.3e-04
#   Iteración 100/100, Pérdida: 0.0022, Mejor L2: inf
#   Fallo para const=1.3e-04. Nuevo límite inferior: 1.3e-04
#
# Búsqueda binaria paso 5/5, const = 1.9e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-20-2406008800.py in <cell line: 0>()
#      85         # Crear y ejecutar ataque
#      86         adv = Adversarial(fmodel, Misclassification(), img_np, orig_lbl, distance=MSE)
# ---> 87         attack(adv, **hypers)
#      88
#      89         # Si exitoso, almacenar
#
# /content/attacks/base.py in wrapper(self, input_or_adv, label, unpack, **kwargs)
#     134         else:
#     135             try:
# --> 136                 _ = call_fn(self, a, label=None, unpack=None, **kwargs)
#     137                 assert _ is None, 'decorated __call__ method must return None'
#     138             except StopAttack:
#
# /content/attacks/carlini_wagner.py in __call__(self, input_or_adv, label, unpack, binary_search_steps, max_iterations, confidence, learning_rate, initial_const, abort_early)
#      70                 x, dxdw = to_model_space(w) # x es la imagen, dxdw es el gradiente de la transformación
#      71
# ---> 72                 logits, is_adv = a.predictions(x, strict=False)
#      73
#      74                 loss, dldx = self.loss_function(a, x, logits, confidence, const)
#
# /content/adversarial.py in predictions(self, image, strict, return_details)
#     304
#     305         self._total_prediction_calls += 1
# --> 306         predictions = self.__model.predictions(image)
#     307         is_adversarial, is_best, distance = self.__is_adversarial(
#     308             image, predictions, in_bounds)
#
# /content/models/base_models.py in predictions(self, image)
#     158
#     159         """
# --> 160         return np.squeeze(self.batch_predictions(image[np.newaxis]), axis=0)
#     161
#     162     @abstractmethod
#
# /content/models/pytorch.py in batch_predictions(self, images)
#      47
#      48         with torch.no_grad():
# ---> 49             predictions = self._model(images)
#      50         predictions = predictions.to("cpu").detach().numpy()
#      51         return predictions
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/densenet.py in forward(self, x)
#     211
#     212     def forward(self, x: Tensor) -> Tensor:
# --> 213         features = self.features(x)
#     214         out = F.relu(features, inplace=True)
#     215         out = F.adaptive_avg_pool2d(out, (1, 1))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248     def forward(self, input):
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/densenet.py in forward(self, init_features)
#     120         features = [init_features]
#     121         for name, layer in self.items():
# --> 122             new_features = layer(features)
#     123             features.append(new_features)
#     124         return torch.cat(features, 1)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/densenet.py in forward(self, input)
#      86             bottleneck_output = self.call_checkpoint_bottleneck(prev_features)
#      87         else:
# ---> 88             bottleneck_output = self.bn_function(prev_features)
#      89
#      90         new_features = self.conv2(self.relu2(self.norm2(bottleneck_output)))
#
# /usr/local/lib/python3.11/dist-packages/torchvision/models/densenet.py in bn_function(self, inputs)
#      47     def bn_function(self, inputs: List[Tensor]) -> Tensor:
#      48         concated_features = torch.cat(inputs, 1)
# ---> 49         bottleneck_output = self.conv1(self.relu1(self.norm1(concated_features)))  # noqa: T484
#      50         return bottleneck_output
#      51
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in forward(self, input)
#     552
#     553     def forward(self, input: Tensor) -> Tensor:
# --> 554         return self._conv_forward(input, self.weight, self.bias)
#     555
#     556
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/conv.py in _conv_forward(self, input, weight, bias)
#     547                 self.groups,
#     548             )
# --> 549         return F.conv2d(
#     550             input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551         )
#
# KeyboardInterrupt:

# %%
# --- Celda 6: Guardar Todos los Resultados y Pesos en Google Drive ---

import os
import shutil
import numpy as np
from google.colab import drive

# 1) Montar Google Drive
if not os.path.ismount('/content/drive'):
    drive.mount('/content/drive')

# 2) Directorio base en Drive
save_dir = '/content/drive/MyDrive/XRay_Adversarial_Data/'
os.makedirs(save_dir, exist_ok=True)

# 3) Guardar arrays de cada modelo
for name, res in results.items():
    benign_arr = np.stack(res['benign'], axis=0) if res['benign'] else np.empty((0,))
    adv_arr    = np.stack(res['adversarial'], axis=0) if res['adversarial'] else np.empty((0,))
    dist_arr   = np.array(res['distance'])

    np.save(os.path.join(save_dir, f"{name}_benign.npy"),        benign_arr)
    np.save(os.path.join(save_dir, f"{name}_adversarial.npy"),   adv_arr)
    np.save(os.path.join(save_dir, f"{name}_distances.npy"),     dist_arr)

# 4) Copiar checkpoints (.pth) de cada modelo
for name, (_, weight_path) in model_defs.items():
    if os.path.exists(weight_path):
        dest_path = os.path.join(save_dir, os.path.basename(weight_path))
        shutil.copy(weight_path, dest_path)
        print(f"Checkpoint guardado: {dest_path}")

# 5) Informar archivos guardados
print("\nArchivos en:", save_dir)
for fname in sorted(os.listdir(save_dir)):
    print(" -", fname)
# Out:
# Checkpoint guardado: /content/drive/MyDrive/XRay_Adversarial_Data/resnet18_best.pth
# Checkpoint guardado: /content/drive/MyDrive/XRay_Adversarial_Data/resnet50_best.pth
# Checkpoint guardado: /content/drive/MyDrive/XRay_Adversarial_Data/densenet121_best.pth
# Checkpoint guardado: /content/drive/MyDrive/XRay_Adversarial_Data/efficientnet_b0_best.pth
# Checkpoint guardado: /content/drive/MyDrive/XRay_Adversarial_Data/vgg19_best.pth
#
# Archivos en: /content/drive/MyDrive/XRay_Adversarial_Data/
#  - adv_distances_xray.npy
#  - adv_images_xray.npy
#  - benign_images_xray.npy
#  - densenet121_best.pth
#  - efficientnet_b0_best.pth
#  - resnet18_adversarial.npy
#  - resnet18_benign.npy
#  - resnet18_best.pth
#  - resnet18_distances.npy
#  - resnet18_xray_best.pth
#  - resnet50_adversarial.npy
#  - resnet50_benign.npy
#  - resnet50_best.pth
#  - resnet50_distances.npy
#  - vgg19_best.pth
